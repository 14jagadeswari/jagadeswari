# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Downloads/rainfall in india 1901-2015.csv")

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
data.groupby(['SUBDIVISION']).count()
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data1=data.loc[(data.YEAR<=2010)]

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
# 4110                LAKSHADWEEP  2010  18.8    0.0    1.2   35.6   79.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data1=data.loc[(data.YEAR<2010)]

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4105                LAKSHADWEEP  2005  17.6   11.1    0.0   37.0   92.8
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data1.tail(5)
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR   APR    MAY    JUN    JUL    AUG  \
# 4105  LAKSHADWEEP  2005  17.6  11.1    0.0  37.0   92.8  248.5  378.9  102.4
# 4106  LAKSHADWEEP  2006  20.1   0.0   33.0   0.3  327.9  286.9  172.3  150.7
# 4107  LAKSHADWEEP  2007   2.5   4.2    0.2  22.2  166.2  573.4  427.4  294.7
# 4108  LAKSHADWEEP  2008   5.5  19.8  120.7  15.8  180.4  254.6  363.9  206.6
# 4109  LAKSHADWEEP  2009   4.7   1.5    0.1  18.1  162.1  401.2  266.4  185.0
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 4105  278.0  164.2  218.3   26.6  1575.4     28.7    129.8   1007.8    409.1
# 4106  318.5  119.1  158.9   10.9  1598.6     20.1    361.2    928.4    288.9
# 4107  457.5  256.1   47.6  109.6  2361.6      6.7    188.6   1753.0    413.3
# 4108  108.9  252.9   67.6  130.1  1726.8     25.3    316.9    934.0    450.6
# 4109  145.1   87.4  166.2  132.3  1570.1      6.2    180.3    997.7    385.9

# %%
data1.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             3
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         25
# Jan-Feb         5
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1=data.drop(['Jan-Feb','Mar-May','Jun-Sep','Oct-Dec'],axis=1)

# %%
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data1['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
data1.groupby(['SUBDIVISION']).count()
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data2=data1.loc[(data1.SUBDIVISION=="TELANGANA")]

# %%
data2
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#         SEP    OCT   NOV  DEC  ANNUAL
# 3197   77.7   75.5  12.2  0.0   827.7
# ...

# %%
data2.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# dtype: int64

# %%
data2=data2.fillna(data2.median())
# Out:
# /tmp/ipykernel_6103/1483159317.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2=data2.fillna(data2.median())

# %%
data2.tail(150)
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#         SEP    OCT   NOV  DEC  ANNUAL
# 3197   77.7   75.5  12.2  0.0   827.7
# ...

# %%
data2.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# dtype: int64

# %%
data2['ANNUAL RAIN']=data2.apply(lambda row: row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)

# %%
data2
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#         SEP    OCT   NOV  DEC  ANNUAL  ANNUAL RAIN
# ...

# %%
data2['SWM-JJAS']=data2.apply(lambda row: row.JUN+row.JUL+row.AUG+row.SEP,axis=1)

# %%
data2
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#         SEP    OCT   NOV  DEC  ANNUAL  ANNUAL RAIN  SWM-JJAS
# ...

# %%
data2['NEM-OND']=data2.apply(lambda row: row.OCT+row.NOV+row.DEC,axis=1)

# %%
data2
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 3197   TELANGANA  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2
# 3198   TELANGANA  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8
# 3199   TELANGANA  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7
# 3200   TELANGANA  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0
# 3201   TELANGANA  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 3307   TELANGANA  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9
# 3308   TELANGANA  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9
# 3309   TELANGANA  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6
# 3310   TELANGANA  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2
# 3311   TELANGANA  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5
#
#         SEP    OCT   NOV  DEC  ANNUAL  ANNUAL RAIN  SWM-JJAS  NEM-OND
# ...

# %%
data2=data2.drop(['SUBDIVISION'],axis=1)

# %%
data2
# Out:
#       YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG    SEP    OCT  \
# 3197  1901   6.9  41.8   7.8  45.2  22.0  123.6  237.8  177.2   77.7   75.5
# 3198  1902   0.0   0.0   0.2  10.7   7.3   52.4  146.3  142.8  190.5   41.7
# 3199  1903  12.9   4.6   0.0   9.9  40.7   99.2  505.2  246.7  191.9  155.8
# 3200  1904   0.0   0.0  10.8   0.8  14.7  104.2  139.5   50.0  162.3   44.4
# 3201  1905   0.0   4.3  12.8  27.6  32.2  129.5   82.4  237.3  179.1   19.6
# ...    ...   ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 3307  2011   0.0  11.9   2.6  25.6   9.3   83.9  268.2  225.9  107.6   13.9
# 3308  2012   6.7   0.0   0.2  14.0   8.4  124.4  300.3  229.9  202.4   83.6
# 3309  2013   2.4  29.0   0.2  24.4   8.5  213.4  453.8  230.6  161.4  205.9
# 3310  2014   0.2   2.9  58.3  10.3  73.3   62.3  146.0  205.2  146.8   29.6
# 3311  2015  17.5   0.0  43.0  65.7  23.3  266.9  104.4  160.5  158.3   15.6
#
#        NOV  DEC  ANNUAL  ANNUAL RAIN  SWM-JJAS  NEM-OND
# ...

# %%
cor=data2.corr()

# %%
cor
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000  0.066679 -0.127789  0.103372 -0.057459  0.049107
# JAN          0.066679  1.000000 -0.054219  0.002439  0.017525  0.033719
# FEB         -0.127789 -0.054219  1.000000  0.039952  0.166871  0.022623
# MAR          0.103372  0.002439  0.039952  1.000000  0.062920  0.068031
# APR         -0.057459  0.017525  0.166871  0.062920  1.000000 -0.057561
# MAY          0.049107  0.033719  0.022623  0.068031 -0.057561  1.000000
# JUN          0.032522 -0.107093  0.022467  0.024190  0.021496  0.179190
# JUL          0.097739 -0.056891  0.026066 -0.162996  0.011166 -0.059126
# AUG          0.343648 -0.076973 -0.021750  0.006257  0.019299  0.137449
# SEP         -0.134013 -0.026067 -0.045791 -0.041883 -0.159302 -0.063313
# OCT          0.156396  0.174812 -0.035158 -0.007192 -0.058436  0.229135
# NOV         -0.072673  0.076095  0.048416 -0.142749 -0.100563  0.034746
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
data2=data2.drop(['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC'],axis=1)

# %%
data2
# Out:
#       YEAR  ANNUAL  ANNUAL RAIN  SWM-JJAS  NEM-OND
# 3197  1901   827.7        827.7     616.3     87.7
# 3198  1902   630.4        630.4     532.0     80.2
# 3199  1903  1283.4       1283.5    1043.0    172.4
# 3200  1904   526.7        526.7     456.0     44.4
# 3201  1905   724.9        724.8     628.3     19.6
# ...    ...     ...          ...       ...      ...
# 3307  2011   753.1        753.1     685.6     18.1
# 3308  2012  1008.6       1008.6     857.0    122.3
# 3309  2013  1348.7       1348.7    1059.2    225.0
# 3310  2014   746.4        746.4     560.3     41.1
# 3311  2015   857.3        857.2     690.1     17.6
#
# [115 rows x 5 columns]

# %%
cor=data2.corr()

# %%
cor
# Out:
#                  YEAR    ANNUAL  ANNUAL RAIN  SWM-JJAS   NEM-OND
# YEAR         1.000000  0.192653     0.192611  0.169694  0.114384
# ANNUAL       0.192653  1.000000     1.000000  0.917468  0.458709
# ANNUAL RAIN  0.192611  1.000000     1.000000  0.917503  0.458665
# SWM-JJAS     0.169694  0.917468     0.917503  1.000000  0.129536
# NEM-OND      0.114384  0.458709     0.458665  0.129536  1.000000

# %%
data2=data2.drop(['ANNUAL'],axis=1)

# %%
data2
# Out:
#       YEAR  ANNUAL RAIN  SWM-JJAS  NEM-OND
# 3197  1901        827.7     616.3     87.7
# 3198  1902        630.4     532.0     80.2
# 3199  1903       1283.5    1043.0    172.4
# 3200  1904        526.7     456.0     44.4
# 3201  1905        724.8     628.3     19.6
# ...    ...          ...       ...      ...
# 3307  2011        753.1     685.6     18.1
# 3308  2012       1008.6     857.0    122.3
# 3309  2013       1348.7    1059.2    225.0
# 3310  2014        746.4     560.3     41.1
# 3311  2015        857.2     690.1     17.6
#
# [115 rows x 4 columns]

# %%
cor=data2.corr()

# %%
cor
# Out:
#                  YEAR  ANNUAL RAIN  SWM-JJAS   NEM-OND
# YEAR         1.000000     0.192611  0.169694  0.114384
# ANNUAL RAIN  0.192611     1.000000  0.917503  0.458665
# SWM-JJAS     0.169694     0.917503  1.000000  0.129536
# NEM-OND      0.114384     0.458665  0.129536  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >
